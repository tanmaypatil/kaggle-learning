# %%
import pandas as pd

# %%
df = pd.read_csv("loan_data.csv")

# %%
df
# Out:
#        Income   Age     employment  family_size  earning_members  expenses  \
# 0    100000.0  25.0        service            3                1    120000
# 1    200000.0  35.0  self_employed            5                1    240000
# 2  10000000.0  41.0  self_employed            1                1   1000000
# 3    100000.0  65.0   not_employed            2                1     50000
# 4    500000.0  29.0   not_employed            2                0     50000
# 5   5000000.0  38.0        service            3                2   1000000
# 6    700000.0  30.0        service            3                1    100000
#
#    loan_amount  open_loan_count  open_loan_amount  home_owner Loan_purpose  \
# 0    2000000.0              0.0               0.0       False         home
# 1    2000000.0              3.0         5100000.0        True     business
# 2    5000000.0              0.0               0.0        True     business
# ...
